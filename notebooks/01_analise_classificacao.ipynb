# %%
# Importação de bibliotecas
import pandas as pd
from pycaret.classification import *  # inicializa o ambiente PyCaret para classificação

# %%
# Carrega os dados em um DataFrame pandas:
data = pd.read_csv('../doc/mushrooms.csv', sep=',')
data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
target_col = 'class'  # define a coluna alvo (variável resposta)

# Configuração do ambiente PyCaret:
s = setup(
    data=data,
    target=target_col,
    session_id=1,                        # define uma semente fixa
    feature_selection=True,              # ativa a seleção automática de variáveis
    feature_selection_method='classic',  # utiliza o método padrão de seleção
    remove_multicollinearity=True,       # remove variáveis altamente correlacionadas
    multicollinearity_threshold=0.9,     # corte de correlação (0.9 é o padrão)
    low_variance_threshold=0.05          # remove features de baixa variância (colunas com valores constantes)
)

# Os parâmetros "normalize" e "remove_outliers" não são úteis para o dataset atual, pois ele não possui variáveis numéricas.
# O parâmetro "fix_imbalance" também não é necessário aqui porque a variável resposta ("class") está bem balanceada.
# Out:
# <style type="text/css">
# #T_d2a20_row9_col1, #T_d2a20_row16_col1, #T_d2a20_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d2a20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2a20_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d2a20_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2a20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2a20_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d2a20_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2a20_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d2a20_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2a20_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d2a20_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2a20_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_d2a20_row3_col1" class="data row3 col1" >e: 0, p: 1</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2a20_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_d2a20_row4_col1" class="data row4 col1" >(8124, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d2a20_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_d2a20_row5_col1" class="data row5 col1" >(8124, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d2a20_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_d2a20_row6_col1" class="data row6 col1" >(5686, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d2a20_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_d2a20_row7_col1" class="data row7 col1" >(2438, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d2a20_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_d2a20_row8_col1" class="data row8 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d2a20_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_d2a20_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d2a20_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_d2a20_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d2a20_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_d2a20_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d2a20_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_d2a20_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d2a20_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_d2a20_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d2a20_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_d2a20_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d2a20_row15_col0" class="data row15 col0" >Low variance threshold</td>
#       <td id="T_d2a20_row15_col1" class="data row15 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d2a20_row16_col0" class="data row16 col0" >Remove multicollinearity</td>
#       <td id="T_d2a20_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d2a20_row17_col0" class="data row17 col0" >Multicollinearity threshold</td>
#       <td id="T_d2a20_row17_col1" class="data row17 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d2a20_row18_col0" class="data row18 col0" >Feature selection</td>
#       <td id="T_d2a20_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d2a20_row19_col0" class="data row19 col0" >Feature selection method</td>
#       <td id="T_d2a20_row19_col1" class="data row19 col1" >classic</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d2a20_row20_col0" class="data row20 col0" >Feature selection estimator</td>
#       <td id="T_d2a20_row20_col1" class="data row20 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d2a20_row21_col0" class="data row21 col0" >Number of features selected</td>
#       <td id="T_d2a20_row21_col1" class="data row21 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d2a20_row22_col0" class="data row22 col0" >Fold Generator</td>
#       <td id="T_d2a20_row22_col1" class="data row22 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d2a20_row23_col0" class="data row23 col0" >Fold Number</td>
#       <td id="T_d2a20_row23_col1" class="data row23 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d2a20_row24_col0" class="data row24 col0" >CPU Jobs</td>
#       <td id="T_d2a20_row24_col1" class="data row24 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_d2a20_row25_col0" class="data row25 col0" >Use GPU</td>
#       <td id="T_d2a20_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_d2a20_row26_col0" class="data row26 col0" >Log Experiment</td>
#       <td id="T_d2a20_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_d2a20_row27_col0" class="data row27 col0" >Experiment Name</td>
#       <td id="T_d2a20_row27_col1" class="data row27 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d2a20_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_d2a20_row28_col0" class="data row28 col0" >USI</td>
#       <td id="T_d2a20_row28_col1" class="data row28 col1" >d3ab</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Isto somente exibe a lista de descrições do setup (nomes dos parâmetros utilizados)
# Não era o objetivo, pois a execução acima já gera uma tabela de resultados da função setup
# selected_features = pull()  # puxa o log do último output
# print(selected_features['Description'].values)
# Out:
# ['Session id' 'Target' 'Target type' 'Target mapping'
#  'Original data shape' 'Transformed data shape'
#  'Transformed train set shape' 'Transformed test set shape'
#  'Categorical features' 'Preprocess' 'Imputation type'
#  'Numeric imputation' 'Categorical imputation' 'Maximum one-hot encoding'
#  'Encoding method' 'Low variance threshold' 'Remove multicollinearity'
#  'Multicollinearity threshold' 'Feature selection'
#  'Feature selection method' 'Feature selection estimator'
#  'Number of features selected' 'Fold Generator' 'Fold Number' 'CPU Jobs'
#  'Use GPU' 'Log Experiment' 'Experiment Name' 'USI']

# %%
# Retorna os nomes das colunas utilizadas no processamento do setup
read_features = get_config('X_train').columns.tolist()
print("Features utilizadas:", read_features)
# Out:
# Features utilizadas: ['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root', 'stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat']

# %%
# Exibe as variáveis selecionadas para modelagem após o processamento do setup e One-Hot Encoding (transformação de cada categoria em uma coluna binária)
X_train_transformed = get_config("X_train_transformed")
X_train_transformed.head()
# Out:
#       cap-surface_s  bruises  gill-color_w  population_y
# 7013            1.0      0.0           0.0           0.0
# 2516            0.0      1.0           0.0           0.0
# 3155            0.0      1.0           0.0           1.0
# 4143            1.0      1.0           0.0           0.0
# 95              1.0      1.0           0.0           0.0

# %%
# Compara todos os modelos disponíveis, ordenando pela métrica AUC como prioridade
# Isso treina e avalia todos os modelos selecionados, retornando uma tabela comparativa com métricas
best_model_auc = compare_models(sort='AUC')
# Out:
# <style type="text/css">
# #T_68a3d th {
#   text-align: left;
# }
# #T_68a3d_row0_col0, #T_68a3d_row1_col0, #T_68a3d_row2_col0, #T_68a3d_row3_col0, #T_68a3d_row3_col2, #T_68a3d_row4_col0, #T_68a3d_row4_col2, #T_68a3d_row5_col0, #T_68a3d_row5_col1, #T_68a3d_row5_col2, #T_68a3d_row5_col3, #T_68a3d_row5_col4, #T_68a3d_row5_col5, #T_68a3d_row5_col6, #T_68a3d_row5_col7, #T_68a3d_row6_col0, #T_68a3d_row6_col2, #T_68a3d_row7_col0, #T_68a3d_row7_col1, #T_68a3d_row7_col2, #T_68a3d_row7_col3, #T_68a3d_row7_col4, #T_68a3d_row7_col5, #T_68a3d_row7_col6, #T_68a3d_row7_col7, #T_68a3d_row8_col0, #T_68a3d_row8_col1, #T_68a3d_row8_col2, #T_68a3d_row8_col3, #T_68a3d_row8_col4, #T_68a3d_row8_col5, #T_68a3d_row8_col6, #T_68a3d_row8_col7, #T_68a3d_row9_col0, #T_68a3d_row9_col1, #T_68a3d_row9_col2, #T_68a3d_row9_col3, #T_68a3d_row9_col4, #T_68a3d_row9_col5, #T_68a3d_row9_col6, #T_68a3d_row9_col7, #T_68a3d_row10_col0, #T_68a3d_row10_col1, #T_68a3d_row10_col2, #T_68a3d_row10_col3, #T_68a3d_row10_col4, #T_68a3d_row10_col5, #T_68a3d_row10_col6, #T_68a3d_row10_col7, #T_68a3d_row11_col0, #T_68a3d_row11_col1, #T_68a3d_row11_col2, #T_68a3d_row11_col3, #T_68a3d_row11_col4, #T_68a3d_row11_col5, #T_68a3d_row11_col6, #T_68a3d_row11_col7, #T_68a3d_row12_col0, #T_68a3d_row12_col1, #T_68a3d_row12_col2, #T_68a3d_row12_col3, #T_68a3d_row12_col4, #T_68a3d_row12_col5, #T_68a3d_row12_col6, #T_68a3d_row12_col7, #T_68a3d_row13_col0, #T_68a3d_row13_col1, #T_68a3d_row13_col2, #T_68a3d_row13_col3, #T_68a3d_row13_col4, #T_68a3d_row13_col5, #T_68a3d_row13_col6, #T_68a3d_row13_col7, #T_68a3d_row14_col0, #T_68a3d_row14_col1, #T_68a3d_row14_col2, #T_68a3d_row14_col3, #T_68a3d_row14_col4, #T_68a3d_row14_col5, #T_68a3d_row14_col6, #T_68a3d_row14_col7, #T_68a3d_row15_col0, #T_68a3d_row15_col1, #T_68a3d_row15_col2, #T_68a3d_row15_col3, #T_68a3d_row15_col4, #T_68a3d_row15_col5, #T_68a3d_row15_col6, #T_68a3d_row15_col7 {
#   text-align: left;
# }
# #T_68a3d_row0_col1, #T_68a3d_row0_col2, #T_68a3d_row0_col3, #T_68a3d_row0_col4, #T_68a3d_row0_col5, #T_68a3d_row0_col6, #T_68a3d_row0_col7, #T_68a3d_row1_col1, #T_68a3d_row1_col2, #T_68a3d_row1_col3, #T_68a3d_row1_col4, #T_68a3d_row1_col5, #T_68a3d_row1_col6, #T_68a3d_row1_col7, #T_68a3d_row2_col1, #T_68a3d_row2_col2, #T_68a3d_row2_col3, #T_68a3d_row2_col4, #T_68a3d_row2_col5, #T_68a3d_row2_col6, #T_68a3d_row2_col7, #T_68a3d_row3_col1, #T_68a3d_row3_col3, #T_68a3d_row3_col4, #T_68a3d_row3_col5, #T_68a3d_row3_col6, #T_68a3d_row3_col7, #T_68a3d_row4_col1, #T_68a3d_row4_col3, #T_68a3d_row4_col4, #T_68a3d_row4_col5, #T_68a3d_row4_col6, #T_68a3d_row4_col7, #T_68a3d_row6_col1, #T_68a3d_row6_col3, #T_68a3d_row6_col4, #T_68a3d_row6_col5, #T_68a3d_row6_col6, #T_68a3d_row6_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_68a3d_row0_col8, #T_68a3d_row1_col8, #T_68a3d_row2_col8, #T_68a3d_row3_col8, #T_68a3d_row4_col8, #T_68a3d_row5_col8, #T_68a3d_row6_col8, #T_68a3d_row7_col8, #T_68a3d_row8_col8, #T_68a3d_row9_col8, #T_68a3d_row10_col8, #T_68a3d_row11_col8, #T_68a3d_row12_col8, #T_68a3d_row13_col8, #T_68a3d_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_68a3d_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_68a3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68a3d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_68a3d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_68a3d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_68a3d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_68a3d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_68a3d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_68a3d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_68a3d_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_68a3d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68a3d_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_68a3d_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_68a3d_row0_col1" class="data row0 col1" >0.8679</td>
#       <td id="T_68a3d_row0_col2" class="data row0 col2" >0.9271</td>
#       <td id="T_68a3d_row0_col3" class="data row0 col3" >0.8679</td>
#       <td id="T_68a3d_row0_col4" class="data row0 col4" >0.8740</td>
#       <td id="T_68a3d_row0_col5" class="data row0 col5" >0.8671</td>
#       <td id="T_68a3d_row0_col6" class="data row0 col6" >0.7355</td>
#       <td id="T_68a3d_row0_col7" class="data row0 col7" >0.7415</td>
#       <td id="T_68a3d_row0_col8" class="data row0 col8" >0.1770</td>
#     </tr>
#     <tr>
#       <th id="T_68a3d_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_68a3d_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_68a3d_row1_col1" class="data row1 col1" >0.8679</td>
#       <td id="T_68a3d_row1_col2" class="data row1 col2" >0.9271</td>
#       <td id="T_68a3d_row1_col3" class="data row1 col3" >0.8679</td>
#       <td id="T_68a3d_row1_col4" class="data row1 col4" >0.8740</td>
#       <td id="T_68a3d_row1_col5" class="data row1 col5" >0.8671</td>
#       <td id="T_68a3d_row1_col6" class="data row1 col6" >0.7355</td>
#       <td id="T_68a3d_row1_col7" class="data row1 col7" >0.7415</td>
#       <td id="T_68a3d_row1_col8" class="data row1 col8" >0.2040</td>
#     </tr>
#     <tr>
#       <th id="T_68a3d_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_68a3d_row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_68a3d_row2_col1" class="data row2 col1" >0.8679</td>
#       <td id="T_68a3d_row2_col2" class="data row2 col2" >0.9271</td>
#       <td id="T_68a3d_row2_col3" class="data row2 col3" >0.8679</td>
#       <td id="T_68a3d_row2_col4" class="data row2 col4" >0.8740</td>
#       <td id="T_68a3d_row2_col5" class="data row2 col5" >0.8671</td>
#       <td id="T_68a3d_row2_col6" class="data row2 col6" >0.7355</td>
#       <td id="T_68a3d_row2_col7" class="data row2 col7" >0.7415</td>
#       <td id="T_68a3d_row2_col8" class="data row2 col8" >0.4530</td>
#     </tr>
#     <tr>
#       <th id="T_68a3d_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_68a3d_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_68a3d_row3_col1" class="data row3 col1" >0.8679</td>
#       <td id="T_68a3d_row3_col2" class="data row3 col2" >0.9270</td>
#       <td id="T_68a3d_row3_col3" class="data row3 col3" >0.8679</td>
#       <td id="T_68a3d_row3_col4" class="data row3 col4" >0.8740</td>
#       <td id="T_68a3d_row3_col5" class="data row3 col5" >0.8671</td>
#       <td id="T_68a3d_row3_col6" class="data row3 col6" >0.7355</td>
#       <td id="T_68a3d_row3_col7" class="data row3 col7" >0.7415</td>
#       <td id="T_68a3d_row3_col8" class="data row3 col8" >0.2200</td>
#     </tr>
#     <tr>
#       <th id="T_68a3d_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_68a3d_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_68a3d_row4_col1" class="data row4 col1" >0.8679</td>
#       <td id="T_68a3d_row4_col2" class="data row4 col2" >0.9270</td>
#       <td id="T_68a3d_row4_col3" class="data row4 col3" >0.8679</td>
#       <td id="T_68a3d_row4_col4" class="data row4 col4" >0.8740</td>
#       <td id="T_68a3d_row4_col5" class="data row4 col5" >0.8671</td>
#       <td id="T_68a3d_row4_col6" class="data row4 col6" >0.7355</td>
#       <td id="T_68a3d_row4_col7" class="data row4 col7" >0.7415</td>
#       <td id="T_68a3d_row4_col8" class="data row4 col8" >0.1910</td>
#     </tr>
#     <tr>
#       <th id="T_68a3d_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_68a3d_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_68a3d_row5_col1" class="data row5 col1" >0.8674</td>
#       <td id="T_68a3d_row5_col2"

# %%
# Cria um modelo com base no melhor que foi selecionado a partir da comparação
best_model = create_model(best_model_auc)
# Out:
# <style type="text/css">
# #T_b1a3d_row10_col0, #T_b1a3d_row10_col1, #T_b1a3d_row10_col2, #T_b1a3d_row10_col3, #T_b1a3d_row10_col4, #T_b1a3d_row10_col5, #T_b1a3d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b1a3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1a3d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b1a3d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b1a3d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b1a3d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b1a3d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b1a3d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b1a3d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1a3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1a3d_row0_col0" class="data row0 col0" >0.7996</td>
#       <td id="T_b1a3d_row0_col1" class="data row0 col1" >0.8822</td>
#       <td id="T_b1a3d_row0_col2" class="data row0 col2" >0.7996</td>
#       <td id="T_b1a3d_row0_col3" class="data row0 col3" >0.8019</td>
#       <td id="T_b1a3d_row0_col4" class="data row0 col4" >0.7988</td>
#       <td id="T_b1a3d_row0_col5" class="data row0 col5" >0.5975</td>
#       <td id="T_b1a3d_row0_col6" class="data row0 col6" >0.6005</td>
#     </tr>
#     <tr>
#       <th id="T_b1a3d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1a3d_row1_col0" class="data row1 col0" >0.9104</td>
#       <td id="T_b1a3d_row1_col1" class="data row1 col1" >0.9494</td>
#       <td id="T_b1a3d_row1_col2" class="data row1 col2" >0.9104</td>
#       <td id="T_b1a3d_row1_col3" class="data row1 col3" >0.9107</td>
#       <td id="T_b1a3d_row1_col4" class="data row1 col4" >0.9103</td>
#       <td id="T_b1a3d_row1_col5" class="data row1 col5" >0.8203</td>
#       <td id="T_b1a3d_row1_col6" class="data row1 col6" >0.8207</td>
#     </tr>
#     <tr>
#       <th id="T_b1a3d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b1a3d_row2_col0" class="data row2 col0" >0.9174</td>
#       <td id="T_b1a3d_row2_col1" class="data row2 col1" >0.9523</td>
#       <td id="T_b1a3d_row2_col2" class="data row2 col2" >0.9174</td>
#       <td id="T_b1a3d_row2_col3" class="data row2 col3" >0.9177</td>
#       <td id="T_b1a3d_row2_col4" class="data row2 col4" >0.9173</td>
#       <td id="T_b1a3d_row2_col5" class="data row2 col5" >0.8344</td>
#       <td id="T_b1a3d_row2_col6" class="data row2 col6" >0.8348</td>
#     </tr>
#     <tr>
#       <th id="T_b1a3d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b1a3d_row3_col0" class="data row3 col0" >0.8858</td>
#       <td id="T_b1a3d_row3_col1" class="data row3 col1" >0.9478</td>
#       <td id="T_b1a3d_row3_col2" class="data row3 col2" >0.8858</td>
#       <td id="T_b1a3d_row3_col3" class="data row3 col3" >0.8866</td>
#       <td id="T_b1a3d_row3_col4" class="data row3 col4" >0.8856</td>
#       <td id="T_b1a3d_row3_col5" class="data row3 col5" >0.7708</td>
#       <td id="T_b1a3d_row3_col6" class="data row3 col6" >0.7719</td>
#     </tr>
#     <tr>
#       <th id="T_b1a3d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b1a3d_row4_col0" class="data row4 col0" >0.8770</td>
#       <td id="T_b1a3d_row4_col1" class="data row4 col1" >0.9416</td>
#       <td id="T_b1a3d_row4_col2" class="data row4 col2" >0.8770</td>
#       <td id="T_b1a3d_row4_col3" class="data row4 col3" >0.8793</td>
#       <td id="T_b1a3d_row4_col4" class="data row4 col4" >0.8766</td>
#       <td id="T_b1a3d_row4_col5" class="data row4 col5" >0.7528</td>
#       <td id="T_b1a3d_row4_col6" class="data row4 col6" >0.7556</td>
#     </tr>
#     <tr>
#       <th id="T_b1a3d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b1a3d_row5_col0" class="data row5 col0" >0.9033</td>
#       <td id="T_b1a3d_row5_col1" class="data row5 col1" >0.9444</td>
#       <td id="T_b1a3d_row5_col2" class="data row5 col2" >0.9033</td>
#       <td id="T_b1a3d_row5_col3" class="data row5 col3" >0.9043</td>
#       <td id="T_b1a3d_row5_col4" class="data row5 col4" >0.9034</td>
#       <td id="T_b1a3d_row5_col5" class="data row5 col5" >0.8067</td>
#       <td id="T_b1a3d_row5_col6" class="data row5 col6" >0.8076</td>
#     </tr>
#     <tr>
#       <th id="T_b1a3d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b1a3d_row6_col0" class="data row6 col0" >0.8046</td>
#       <td id="T_b1a3d_row6_col1" class="data row6 col1" >0.8887</td>
#       <td id="T_b1a3d_row6_col2" class="data row6 col2" >0.8046</td>
#       <td id="T_b1a3d_row6_col3" class="data row6 col3" >0.8410</td>
#       <td id="T_b1a3d_row6_col4" class="data row6 col4" >0.8006</td>
#       <td id="T_b1a3d_row6_col5" class="data row6 col5" >0.6130</td>
#       <td id="T_b1a3d_row6_col6" class="data row6 col6" >0.6464</td>
#     </tr>
#     <tr>
#       <th id="T_b1a3d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b1a3d_row7_col0" class="data row7 col0" >0.8169</td>
#       <td id="T_b1a3d_row7_col1" class="data row7 col1" >0.9257</td>
#       <td id="T_b1a3d_row7_col2" class="data row7 col2" >0.8169</td>
#       <td id="T_b1a3d_row7_col3" class="data row7 col3" >0.8193</td>
#       <td id="T_b1a3d_row7_col4" class="data row7 col4" >0.8169</td>
#       <td id="T_b1a3d_row7_col5" class="data row7 col5" >0.6343</td>
#       <td id="T_b1a3d_row7_col6" class="data row7 col6" >0.6363</td>
#     </tr>
#     <tr>
#       <th id="T_b1a3d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b1a3d_row8_col0" class="data row8 col0" >0.9102</td>
#       <td id="T_b1a3d_row8_col1" class="data row8 col1" >0.9390</td>
#       <td id="T_b1a3d_row8_col2" class="data row8 col2" >0.9102</td>
#       <td id="T_b1a3d_row8_col3" class="data row8 col3" >0.9132</td>
#       <td id="T_b1a3d_row8_col4" class="data row8 col4" >0.9099</td>
#       <td id="T_b1a3d_row8_col5" class="data row8 col5" >0.8196</td>
#       <td id="T_b1a3d_row8_col6" class="data row8 col6" >0.8229</td>
#     </tr>
#     <tr>
#       <th id="T_b1a3d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b1a3d_row9_col0" class="data row9 col0" >0.8539</td>
#       <td id="T_b1a3d_row9_col1" class="data row9 col1" >0.8997</td>
#       <td id="T_b1a3d_row9_col2" class="data row9 col2" >0.8539</td>
#       <td id="T_b1a3d_row9_col3" class="data row9 col3" >0.8658</td>
#       <td id="T_b1a3d_row9_col4" class="data row9 col4" >0.8521</td>
#       <td id="T_b1a3d_row9_col5" class="data row9 col5" >0.7054</td>
#       <td id="T_b1a3d_row9_col6" class="data row9 col6" >0.7183</td>
#     </tr>
#     <tr>
#       <th id="T_b1a3d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b1a3d_row10_col0" class="data row10 col0" >0.8679</td>
#       <td id="T_b1a3d_row10_col1" class="data row10 col1" >0.9271</td>
#       <td id="T_b1a3d_row10_col2" class="data row10 col2" >0.8679</td>
#       <td id="T_b1a3d_row10_col3" class="data row10 col3" >0.8740</td>
#       <td id="T_b1a3d_row10_col4" class="data row10 col4" >0.8671</td>
#       <td id="T_b1a3d_row10_col5" class="data row10 col5" >0.7355</td>
#       <td id="T_b1a3d_row10_col6" class="data row10 col6" >0.7415</td>
#     </tr>
#     <tr>
#       <th id="T_b1a3d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b1a3d_row11_col0" class="data row11 col0" >0.0438</td>
#       <td id="T_b1a3d_row11_col1" class="data row11 col1" >0.0254</td>
#       <td id="T_b1a3d_row11_col2" class="data row11 col2" >0.0438</td>
#       <td id="T_b1a3d_row11_col3" class="data row11 col3" >0.0390</td>
#       <td id="T_b1a3d_row11_col4

# %%
# Ajusta hiperparâmetros, otimizando AUC
tuned_model = tune_model(best_model, optimize='auc')

# Por padrão, o PyCaret usa Random Search no parâmetro "search_algorithm".
# Out:
# <style type="text/css">
# #T_fb82c_row10_col0, #T_fb82c_row10_col1, #T_fb82c_row10_col2, #T_fb82c_row10_col3, #T_fb82c_row10_col4, #T_fb82c_row10_col5, #T_fb82c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fb82c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb82c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fb82c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fb82c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fb82c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fb82c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fb82c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fb82c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb82c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb82c_row0_col0" class="data row0 col0" >0.7996</td>
#       <td id="T_fb82c_row0_col1" class="data row0 col1" >0.8822</td>
#       <td id="T_fb82c_row0_col2" class="data row0 col2" >0.7996</td>
#       <td id="T_fb82c_row0_col3" class="data row0 col3" >0.8019</td>
#       <td id="T_fb82c_row0_col4" class="data row0 col4" >0.7988</td>
#       <td id="T_fb82c_row0_col5" class="data row0 col5" >0.5975</td>
#       <td id="T_fb82c_row0_col6" class="data row0 col6" >0.6005</td>
#     </tr>
#     <tr>
#       <th id="T_fb82c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb82c_row1_col0" class="data row1 col0" >0.9104</td>
#       <td id="T_fb82c_row1_col1" class="data row1 col1" >0.9494</td>
#       <td id="T_fb82c_row1_col2" class="data row1 col2" >0.9104</td>
#       <td id="T_fb82c_row1_col3" class="data row1 col3" >0.9107</td>
#       <td id="T_fb82c_row1_col4" class="data row1 col4" >0.9103</td>
#       <td id="T_fb82c_row1_col5" class="data row1 col5" >0.8203</td>
#       <td id="T_fb82c_row1_col6" class="data row1 col6" >0.8207</td>
#     </tr>
#     <tr>
#       <th id="T_fb82c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fb82c_row2_col0" class="data row2 col0" >0.9174</td>
#       <td id="T_fb82c_row2_col1" class="data row2 col1" >0.9523</td>
#       <td id="T_fb82c_row2_col2" class="data row2 col2" >0.9174</td>
#       <td id="T_fb82c_row2_col3" class="data row2 col3" >0.9177</td>
#       <td id="T_fb82c_row2_col4" class="data row2 col4" >0.9173</td>
#       <td id="T_fb82c_row2_col5" class="data row2 col5" >0.8344</td>
#       <td id="T_fb82c_row2_col6" class="data row2 col6" >0.8348</td>
#     </tr>
#     <tr>
#       <th id="T_fb82c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fb82c_row3_col0" class="data row3 col0" >0.8858</td>
#       <td id="T_fb82c_row3_col1" class="data row3 col1" >0.9478</td>
#       <td id="T_fb82c_row3_col2" class="data row3 col2" >0.8858</td>
#       <td id="T_fb82c_row3_col3" class="data row3 col3" >0.8866</td>
#       <td id="T_fb82c_row3_col4" class="data row3 col4" >0.8856</td>
#       <td id="T_fb82c_row3_col5" class="data row3 col5" >0.7708</td>
#       <td id="T_fb82c_row3_col6" class="data row3 col6" >0.7719</td>
#     </tr>
#     <tr>
#       <th id="T_fb82c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fb82c_row4_col0" class="data row4 col0" >0.8770</td>
#       <td id="T_fb82c_row4_col1" class="data row4 col1" >0.9416</td>
#       <td id="T_fb82c_row4_col2" class="data row4 col2" >0.8770</td>
#       <td id="T_fb82c_row4_col3" class="data row4 col3" >0.8793</td>
#       <td id="T_fb82c_row4_col4" class="data row4 col4" >0.8766</td>
#       <td id="T_fb82c_row4_col5" class="data row4 col5" >0.7528</td>
#       <td id="T_fb82c_row4_col6" class="data row4 col6" >0.7556</td>
#     </tr>
#     <tr>
#       <th id="T_fb82c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fb82c_row5_col0" class="data row5 col0" >0.9033</td>
#       <td id="T_fb82c_row5_col1" class="data row5 col1" >0.9444</td>
#       <td id="T_fb82c_row5_col2" class="data row5 col2" >0.9033</td>
#       <td id="T_fb82c_row5_col3" class="data row5 col3" >0.9043</td>
#       <td id="T_fb82c_row5_col4" class="data row5 col4" >0.9034</td>
#       <td id="T_fb82c_row5_col5" class="data row5 col5" >0.8067</td>
#       <td id="T_fb82c_row5_col6" class="data row5 col6" >0.8076</td>
#     </tr>
#     <tr>
#       <th id="T_fb82c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fb82c_row6_col0" class="data row6 col0" >0.8046</td>
#       <td id="T_fb82c_row6_col1" class="data row6 col1" >0.8887</td>
#       <td id="T_fb82c_row6_col2" class="data row6 col2" >0.8046</td>
#       <td id="T_fb82c_row6_col3" class="data row6 col3" >0.8410</td>
#       <td id="T_fb82c_row6_col4" class="data row6 col4" >0.8006</td>
#       <td id="T_fb82c_row6_col5" class="data row6 col5" >0.6130</td>
#       <td id="T_fb82c_row6_col6" class="data row6 col6" >0.6464</td>
#     </tr>
#     <tr>
#       <th id="T_fb82c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fb82c_row7_col0" class="data row7 col0" >0.8169</td>
#       <td id="T_fb82c_row7_col1" class="data row7 col1" >0.9257</td>
#       <td id="T_fb82c_row7_col2" class="data row7 col2" >0.8169</td>
#       <td id="T_fb82c_row7_col3" class="data row7 col3" >0.8193</td>
#       <td id="T_fb82c_row7_col4" class="data row7 col4" >0.8169</td>
#       <td id="T_fb82c_row7_col5" class="data row7 col5" >0.6343</td>
#       <td id="T_fb82c_row7_col6" class="data row7 col6" >0.6363</td>
#     </tr>
#     <tr>
#       <th id="T_fb82c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fb82c_row8_col0" class="data row8 col0" >0.9102</td>
#       <td id="T_fb82c_row8_col1" class="data row8 col1" >0.9390</td>
#       <td id="T_fb82c_row8_col2" class="data row8 col2" >0.9102</td>
#       <td id="T_fb82c_row8_col3" class="data row8 col3" >0.9132</td>
#       <td id="T_fb82c_row8_col4" class="data row8 col4" >0.9099</td>
#       <td id="T_fb82c_row8_col5" class="data row8 col5" >0.8196</td>
#       <td id="T_fb82c_row8_col6" class="data row8 col6" >0.8229</td>
#     </tr>
#     <tr>
#       <th id="T_fb82c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fb82c_row9_col0" class="data row9 col0" >0.8539</td>
#       <td id="T_fb82c_row9_col1" class="data row9 col1" >0.8997</td>
#       <td id="T_fb82c_row9_col2" class="data row9 col2" >0.8539</td>
#       <td id="T_fb82c_row9_col3" class="data row9 col3" >0.8658</td>
#       <td id="T_fb82c_row9_col4" class="data row9 col4" >0.8521</td>
#       <td id="T_fb82c_row9_col5" class="data row9 col5" >0.7054</td>
#       <td id="T_fb82c_row9_col6" class="data row9 col6" >0.7183</td>
#     </tr>
#     <tr>
#       <th id="T_fb82c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_fb82c_row10_col0" class="data row10 col0" >0.8679</td>
#       <td id="T_fb82c_row10_col1" class="data row10 col1" >0.9271</td>
#       <td id="T_fb82c_row10_col2" class="data row10 col2" >0.8679</td>
#       <td id="T_fb82c_row10_col3" class="data row10 col3" >0.8740</td>
#       <td id="T_fb82c_row10_col4" class="data row10 col4" >0.8671</td>
#       <td id="T_fb82c_row10_col5" class="data row10 col5" >0.7355</td>
#       <td id="T_fb82c_row10_col6" class="data row10 col6" >0.7415</td>
#     </tr>
#     <tr>
#       <th id="T_fb82c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_fb82c_row11_col0" class="data row11 col0" >0.0438</td>
#       <td id="T_fb82c_row11_col1" class="data row11 col1" >0.0254</td>
#       <td id="T_fb82c_row11_col2" class="data row11 col2" >0.0438</td>
#       <td id="T_fb82c_row11_col3" class="data row11 col3" >0.0390</td>
#       <td id="T_fb82c_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# Avalia o modelo após ajuste
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Avalia o modelo original selecionado a partir da comparação
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Finalizando o modelo (blend dos melhores)

# Etapa ignorada por conta do retorno da função "tune_model()":
# "Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one)."

# %%
# Interpretando o modelo
interpret_model(best_model)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Interpretando o modelo
# ----> 2 interpret_model(best_model)
#
# File c:\Users\am_cy\git\ambiente_matematica_computacional\env\lib\site-packages\pycaret\utils\generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File c:\Users\am_cy\git\ambiente_matematica_computacional\env\lib\site-packages\pycaret\classification\functional.py:1905, in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1807 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1808 def interpret_model(
#    1809     estimator,
#    (...)
#    1817     **kwargs,
#    1818 ):
#    1819     """
#    1820     This function takes a trained model object and returns an interpretation plot
#    1821     based on the test / hold-out set.
#    (...)
#    1902
#    1903     """
# -> 1905     return _CURRENT_EXPERIMENT.interpret_model(
#    1906         estimator=estimator,
#    1907         plot=plot,
#    1908         feature=feature,
#    1909         observation=observation,
#    1910         use_train_data=use_train_data,
#    1911         X_new_sample=X_new_sample,
#    1912         y_new_sample=y_new_sample,
#    1913         save=save,
#    1914         **kwargs,
#    1915     )
#
# File c:\Users\am_cy\git\ambiente_matematica_computacional\env\lib\site-packages\pycaret\classification\oop.py:2249, in ClassificationExperiment.interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    2151 def interpret_model(
#    2152     self,
#    2153     estimator,
#    (...)
#    2161     **kwargs,
#    2162 ):
#    2163     """
#    2164     This function takes a trained model object and returns an interpretation plot
#    2165     based on the test / hold-out set.
#    (...)
#    2246
#    2247     """
# -> 2249     return super().interpret_model(
#    2250         estimator=estimator,
#    2251         plot=plot,
#    2252         feature=feature,
#    2253         observation=observation,
#    2254         use_train_data=use_train_data,
#    2255         X_new_sample=X_new_sample,
#    2256         y_new_sample=y_new_sample,
#    2257         save=save,
#    2258         **kwargs,
#    2259     )
#
# File c:\Users\am_cy\git\ambiente_matematica_computacional\env\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:4051, in _SupervisedExperiment.interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    4049 # checking if shap available
#    4050 if plot in ["summary", "correlation", "reason"]:
# -> 4051     _check_soft_dependencies("shap", extra="analysis", severity="error")
#    4052     import shap
#    4054 # checking if pdpbox is available
#
# File c:\Users\am_cy\git\ambiente_matematica_computacional\env\lib\site-packages\pycaret\utils\_dependencies.py:152, in _check_soft_dependencies(package, severity, extra, install_name)
#     150 if severity == "error":
#     151     logger.exception(f"{msg}")
# --> 152     raise ModuleNotFoundError(msg)
#     153 elif severity == "warning":
#     154     logger.warning(f"{msg}")
#
# ModuleNotFoundError:
# 'shap' is a soft dependency and not included in the pycaret installation. Please run: `pip install shap` to install.
# Alternately, you can install this by running `pip install pycaret[analysis]`

# %%
# Salva o modelo
save_model(best_model, '../doc/resultados/modelo_classificacao_cogumelos')
